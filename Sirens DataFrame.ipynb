# %%
import pandas as pd
import json

# %%
# Create URL to JSON file (alternatively this can be a filepath)
url = './datasets/KSSirensDictionaries.json'

# # Load the first sheet of the JSON file into a data frame
#df = pd.read_json(url)

# print(f'{actor["name"]}')
      
# # View the first ten rows
#df.head()

# %%
with open(url) as data_file:
    data = json.load(data_file)
    df=pd.DataFrame(data['Folder']['Placemark'])
    
#for folder in data['Folder']:
#    coordinates.append(result[u'Placemark'][u'Point'][u'coordinates'])
#df = pd.DataFrame([coordinates]).T
df
DataFrame = df[['Point']].copy()
DataFrame
# Out:
#                                           Point
# 0      {'coordinates': '-95.332985,39.41707,0'}
# 1     {'coordinates': '-95.266657,39.323065,0'}
# 2     {'coordinates': '-95.463333,39.339704,0'}
# 3     {'coordinates': '-95.116174,39.345001,0'}
# 4     {'coordinates': '-95.123121,39.259319,0'}
# 5     {'coordinates': '-95.211377,39.194364,0'}
# 6     {'coordinates': '-95.084937,39.109078,0'}
# 7     {'coordinates': '-95.069316,39.116581,0'}
# 8     {'coordinates': '-95.398487,39.522513,0'}
# 9     {'coordinates': '-95.302792,39.573534,0'}
# 10    {'coordinates': '-95.628278,39.394915,0'}
# 11    {'coordinates': '-95.737545,39.342579,0'}
# 12    {'coordinates': '-95.722345,39.339189,0'}
# 13    {'coordinates': '-95.467576,39.234701,0'}
# 14     {'coordinates': '-95.42362,39.175961,0'}
# 15      {'coordinates': '-95.42521,39.11297,0'}
# 16    {'coordinates': '-95.392863,39.076101,0'}
# 17    {'coordinates': '-95.561786,39.082406,0'}
# 18    {'coordinates': '-99.105488,37.615846,0'}
# 19     {'coordinates': '-98.741899,37.70406,0'}
# 20       {'coordinates': '-98.7629,38.00076,0'}
# 21     {'coordinates': '-98.795655,38.17715,0'}
# 22    {'coordinates': '-98.968419,37.960051,0'}
# 23    {'coordinates': '-98.599631,37.962185,0'}
# 24    {'coordinates': '-98.599395,37.956171,0'}
# 25    {'coordinates': '-98.407792,37.958774,0'}
# 26    {'coordinates': '-98.309111,37.970242,0'}
# 27    {'coordinates': '-98.093045,37.967711,0'}
# 28     {'coordinates': '-95.85803,38.416523,0'}
# 29    {'coordinates': '-95.858073,38.416483,0'}
# ...                                         ...
# 3565  {'coordinates': '-97.340423,35.015469,0'}
# 3566  {'coordinates': '-97.333503,35.014335,0'}
# 3567   {'coordinates': '-95.53344,35.474196,0'}
# 3568  {'coordinates': '-97.154492,34.646193,0'}
# 3569  {'coordinates': '-97.637907,35.145762,0'}
# 3570  {'coordinates': '-97.920274,36.882659,0'}
# 3571  {'coordinates': '-97.142932,33.795042,0'}
# 3572   {'coordinates': '-97.59645,34.161055,0'}
# 3573  {'coordinates': '-97.424853,34.161734,0'}
# 3574   {'coordinates': '-97.48714,34.233732,0'}
# 3575  {'coordinates': '-97.033294,35.974533,0'}
# 3576  {'coordinates': '-97.237474,35.952754,0'}
# 3577   {'coordinates': '-97.25684,35.941029,0'}
# 3578   {'coordinates': '-97.01197,35.808626,0'}
# 3579  {'coordinates': '-96.872538,35.894669,0'}
# 3580  {'coordinates': '-96.905985,36.017804,0'}
# 3581   {'coordinates': '-96.929926,36.22815,0'}
# 3582  {'coordinates': '-97.008773,36.295723,0'}
# 3583  {'coordinates': '-97.454621,36.276092,0'}
# 3584  {'coordinates': '-97.596477,35.952971,0'}
# 3585  {'coordinates': '-97.557349,36.691147,0'}
# 3586   {'coordinates': '-97.444332,36.52795,0'}
# 3587  {'coordinates': '-97.151397,36.560084,0'}
# 3588  {'coordinates': '-95.429601,36.533735,0'}
# 3589  {'coordinates': '-95.710906,36.438014,0'}
# 3590  {'coordinates': '-95.094577,36.875342,0'}
# 3591  {'coordinates': '-95.071467,36.799728,0'}
# 3592  {'coordinates': '-94.848125,36.749837,0'}
# 3593   {'coordinates': '-94.79668,36.420872,0'}
# 3594  {'coordinates': '-97.192091,35.660269,0'}
#
# [3595 rows x 1 columns]
