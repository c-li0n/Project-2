# %%
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, String, Float, Date
import sqlite3
import pandas as pd
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
engine = create_engine('sqlite:///datasets/Tornados22.sqlite', echo=False)
Base.metadata.create_all(engine)
conn = engine.connect()
db_file = ('datasets/tornadodata.csv')

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except sqlite3.Error as e:
        print(e)
 
    return conn

# %%
def create_table(conn, create_table_sql):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    :return:
    """
    try:
        c = conn.cursor()
        c.execute(create_table_sql)
    except sqlite3.Error as e:
        print(e)

# %%
database = "./datasets/Tornados22.sqlite"

# %%
# def main():

sql_create_Tornados22_table = """ CREATE TABLE IF NOT EXISTS Tornados22 (

 
  Stupid Integer not null primary key,
  Segment Varchar (100),
  Date Integer not null,
  Time Integer not null,
  TimeZone Integer not null,
  State1 Varchar (100),
  State2 Varchar (100),
  State3 Varchar (100),
  Fujita Integer not null,
  Fatalities Integer not null,
  Injuries Integer not null,
  Width Varchar (100),
  Length Varchar (100),
  County1 Varchar (100),
  County2 Varchar (100),
  County3 Varchar (100),
  County4 Varchar (100),
  County5 Varchar (100),
  County6 Varchar (100),
  County7 Varchar (100),
  County8 Varchar (100),
  County9 Varchar (100),
  County10 Varchar (100),
  County11 Varchar (100),
  County12 Varchar (100),
  Damage Varchar (100),
  CropLoss Varchar (100),
  TouchdownLat Varchar (100),
  TouchdownLon Varchar (100),
  LiftoffLat Varchar (100),
  LiftoffLon Varchar (100),
  NumberOfStates Integer not null,
  StateTor Varchar (100),
  TorNum Varchar (100),
  RecordStatus Varchar (100)
            ); """

# %%
   # create a database connection
conn = create_connection(database)
 
    # create tables
if conn is not None:
        # create projects table
        create_table(conn, sql_create_Tornados22_table)
 
else:
        print("Error! cannot create the database connection.")
 
 
# if __name__ == '__main__':
#     main()

# %%
conn.commit()

# %%
csv_df = pd.read_csv(db_file, index_col=0)
csv_df.to_sql("Tornados22", conn, if_exists='replace', index=True, index_label="id")
# Out:
# /Users/brant/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-8-fe6256f87e39> in <module>
#       1 csv_df = pd.read_csv(db_file, index_col=0)
# ----> 2 csv_df.to_sql("Tornados22", conn, if_exists='replace', index=True, index_label="id")
#
# ~/.pyenv/versions/3.7.4/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2129                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2130                    dtype=dtype)
# ...

# %%
results = conn.execute('SELECT * FROM Tornados22')
print(results)

# %%
for result in results.fetchall():
    print(result)
# Out:
# ('19500103.29.1', 'Summary', '1/3/1950', '11:00:00', 3, 'Missouri', 'Illinois', '-', '3', 0, 3, '150', '9.5', 'St. Louis', 'Madison', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '$500K-$5M', None, 38.77, -90.22, '38.83', '-90.03', 2, None, 1, 'Unmodified')
# ('19500125.29.2', 'Summary', '1/25/1950', '19:30:00', 3, 'Missouri', '-', '-', '2', 0, 5, '300', '2.3', 'Iron', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '$50K-$500K', None, 37.6, -90.68, '37.63', '-90.65', 1, None, 5, 'Unmodified')
# ('19500126.48.1', 'Summary', '1/26/1950', '18:00:00', 3, 'Texas', '-', '-', '2', 0, 2, '133', '4.7', 'Brooks', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', None, 26.88, -98.12, '26.88', '-98.05', 1, None, 7, 'Unmodified')
# ('19500211.48.2', 'Summary', '2/11/1950', '13:10:00', 3, 'Texas', '-', '-', '2', 0, 0, '400', '9.9', 'Brazoria', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '$5K-$50K', None, 29.42, -95.25, '29.52', '-95.13', 1, None, 8, 'Unmodified')
# ...

# %%
results.fetchall()
# Out:
# []
